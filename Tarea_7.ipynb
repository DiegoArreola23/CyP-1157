# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoArreola23/CyP-1157/blob/main/Tarea_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBLEMA 3.1

# %%
PROPAR = 0
SUMPAR = 0
SUMIMP = 0
CUEPAR = 0
i = 1
while i <= 270:
    NUM = int(input("Dame un número entero: ")) 
    if NUM > 0:
        if ((-1)**NUM) > 0:
            SUMPAR = SUMPAR + NUM
            CUEPAR = CUEPAR + 1
            i = i + 1            
        else:
            SUMIMP = SUMIMP + NUM
            i = i + 1
    else:
        i = i + 1
        print(i)
else:
    PROPAR = SUMPAR/CUEPAR
    print(f"PROPAR = {PROPAR} , SIMIMP = {SUMIMP}")        
     
print("SUMPAR = ",SUMPAR)
print("CUEPAR = ",CUEPAR)
print("SUMIMP = ",SUMIMP)
print("FIN DEL PROGRAMA")

# %% [markdown]
# # PROBLEMA 3.2

# %%
BAND = 'T'
SUMSER = 0
I = 2
while I <= 1800:
    SUMSER = SUMSER + 1
    print("I = ",I)
    if BAND == 'T':
        BAND = 'F'
        I = I + 3
    else:
        BAND = 'T'
        I = I + 2
else:
    print("SUMSER = ", SUMSER)
print("FIN DEL PROGRAMA")
# Out:
# I =  2
# I =  5
# I =  7
# I =  10
# I =  12
# I =  15
# I =  17
# I =  20
# I =  22
# I =  25
# I =  27
# I =  30
# I =  32
# I =  35
# I =  37
# I =  40
# I =  42
# I =  45
# I =  47
# I =  50
# I =  52
# I =  55
# I =  57
# I =  60
# I =  62
# I =  65
# I =  67
# I =  70
# I =  72
# I =  75
# I =  77
# I =  80
# I =  82
# I =  85
# I =  87
# I =  90
# I =  92
# I =  95
# I =  97
# I =  100
# I =  102
# I =  105
# I =  107
# I =  110
# I =  112
# I =  115
# I =  117
# I =  120
# I =  122
# I =  125
# I =  127
# I =  130
# I =  132
# I =  135
# I =  137
# I =  140
# I =  142
# I =  145
# I =  147
# I =  150
# I =  152
# I =  155
# I =  157
# I =  160
# I =  162
# I =  165
# I =  167
# I =  170
# I =  172
# I =  175
# I =  177
# I =  180
# I =  182
# I =  185
# I =  187
# I =  190
# I =  192
# I =  195
# I =  197
# I =  200
# I =  202
# I =  205
# I =  207
# I =  210
# I =  212
# I =  215
# I =  217
# I =  220
# I =  222
# I =  225
# I =  227
# I =  230
# I =  232
# I =  235
# ...

# %% [markdown]
# # PROBLEMA 3.3

# %%
SERIE = 0
N = int(input("Dame un valor entero: "))
BAND = 'T'
I = 1
print("N =",N)
print("BAND = ", BAND)
print("SERIE = ",SERIE)
print("------------------------------------------------------------------")
while I <= N:

        if BAND == 'T':
            SERIE = SERIE + (1/I)
            BAND = 'F'
            print("BAND = ", BAND)
            print("SERIE = ",SERIE)
            print("------------------------------------------------------------------")

        else:
            SERIE = SERIE - (1/I)
            BAND = 'T'

            print("BAND = ", BAND)
            print("SERIE = ",SERIE)
            print("------------------------------------------------------------------")
        I = I + 1

print("FIN DEL PROGRAMA")
# Out:
# Dame un valor entero: 9
# N = 9
# BAND =  T
# SERIE =  0
# ------------------------------------------------------------------
# BAND =  F
# SERIE =  1.0
# ------------------------------------------------------------------
# BAND =  T
# SERIE =  0.5
# ------------------------------------------------------------------
# BAND =  F
# SERIE =  0.8333333333333333
# ------------------------------------------------------------------
# BAND =  T
# SERIE =  0.5833333333333333
# ------------------------------------------------------------------
# BAND =  F
# SERIE =  0.7833333333333332
# ------------------------------------------------------------------
# BAND =  T
# SERIE =  0.6166666666666666
# ------------------------------------------------------------------
# BAND =  F
# SERIE =  0.7595238095238095
# ------------------------------------------------------------------
# BAND =  T
# SERIE =  0.6345238095238095
# ------------------------------------------------------------------
# BAND =  F
# ...

# %% [markdown]
# # PROBLEMA 3.4

# %%
NOM = 0
NSUE = 0
print("NOM = ",NOM)
SUE = float(input("Dame un valor de tipo real: "))
while SUE > -1:
    if SUE < 1000:
        NSUE = SUE*(1.15)
    else:
        NSUE = SUE*(1.12)
    NOM = NOM + NSUE
    print("-----------------------------------------")
    print("NOM = ",NOM)
    SUE = float(input("Dame un valor de tipo real: "))
    print("NSUE = ",NSUE)

print("-----------------------------------------")
print(f"NOM = {NOM}")
print("FIN DEL PROGRAMA")
# Out:
# NOM =  0
# Dame un valor de tipo real: 855
# -----------------------------------------
# NOM =  983.2499999999999
# Dame un valor de tipo real: 760.32
# NSUE =  983.2499999999999
# -----------------------------------------
# NOM =  1857.618
# Dame un valor de tipo real: 1100.20
# NSUE =  874.3679999999999
# -----------------------------------------
# NOM =  3089.842
# Dame un valor de tipo real: 614
# NSUE =  1232.2240000000002
# -----------------------------------------
# NOM =  3795.942
# Dame un valor de tipo real: 2600
# NSUE =  706.0999999999999
# -----------------------------------------
# NOM =  6707.942000000001
# Dame un valor de tipo real: 817.50
# NSUE =  2912.0000000000005
# -----------------------------------------
# NOM =  7648.067000000001
# Dame un valor de tipo real: 1280.30
# NSUE =  940.1249999999999
# -----------------------------------------
# NOM =  9082.003
# Dame un valor de tipo real: 687
# NSUE =  1433.9360000000001
# ...
